# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from fractions import Fraction

import plotly.express as px

pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %matplotlib inline

# %%
#this is a custom function to open each dataset
def open_fuel_year(fuel_year):
    
    df = pd.read_csv('./data_'+str(fuel_year)+'_v2.csv', low_memory=False)

    df['record_year'] = pd.Series(dtype='str')
    new_cols_order = ['record_year'] + df.columns[0:18].to_list()
    
    df = df[new_cols_order]
    for year in years:
        if year == fuel_year:
            df['record_year'] = int(fuel_year)
            print(new_cols_order)    
        
    return df

# %%
clean_df = pd.DataFrame()

years = [2008,2018]

#join the datasets
for fuel_year in years:
    clean_df = pd.concat([clean_df, open_fuel_year(fuel_year)])
    
    print(len(clean_df))
clean_df.reset_index(drop=True, inplace=True)
# Out:
# ['record_year', 'record_year', 'model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region', 'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score', 'smartway']
# 2142
# ['record_year', 'record_year', 'model', 'displ', 'cyl', 'trans', 'drive', 'fuel', 'cert_region', 'veh_class', 'air_pollution_score', 'city_mpg', 'hwy_mpg', 'cmb_mpg', 'greenhouse_gas_score', 'smartway']
# 3746

# %%
clean_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3746 entries, 0 to 3745
# Data columns (total 16 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   record_year           3746 non-null   int64
#  1   record_year           3746 non-null   int64
#  2   model                 3746 non-null   object
#  3   displ                 3746 non-null   float64
#  4   cyl                   3746 non-null   object
#  5   trans                 3746 non-null   object
#  6   drive                 3746 non-null   object
#  7   fuel                  3746 non-null   object
#  8   cert_region           3746 non-null   object
#  9   veh_class             3746 non-null   object
#  10  air_pollution_score   3746 non-null   object
#  11  city_mpg              3746 non-null   object
#  12  hwy_mpg               3746 non-null   object
#  13  cmb_mpg               3746 non-null   object
#  14  greenhouse_gas_score  3746 non-null   object
# ...

# %%
clean_df
# Out:
#       record_year  record_year        model  displ      cyl       trans drive  \
# 0            2008         2008    ACURA MDX    3.7  (6 cyl)     Auto-S5   4WD
# 1            2008         2008    ACURA MDX    3.7  (6 cyl)     Auto-S5   4WD
# 2            2008         2008    ACURA RDX    2.3  (4 cyl)     Auto-S5   4WD
# 3            2008         2008    ACURA RDX    2.3  (4 cyl)     Auto-S5   4WD
# 4            2008         2008     ACURA RL    3.5  (6 cyl)     Auto-S5   4WD
# ...           ...          ...          ...    ...      ...         ...   ...
# 3741         2018         2018  VOLVO XC 90    2.0      4.0  SemiAuto-8   4WD
# 3742         2018         2018  VOLVO XC 90    2.0      4.0  SemiAuto-8   4WD
# 3743         2018         2018  VOLVO XC 90    2.0      4.0  SemiAuto-8   4WD
# 3744         2018         2018  VOLVO XC 90    2.0      4.0  SemiAuto-8   4WD
# 3745         2018         2018  VOLVO XC 90    2.0      4.0  SemiAuto-8   4WD
#
# ...

# %%
clean_df = clean_df.T.drop_duplicates()

# %%
clean_df = clean_df.T
clean_df
# Out:
#      record_year        model displ      cyl       trans drive  \
# 0           2008    ACURA MDX   3.7  (6 cyl)     Auto-S5   4WD
# 1           2008    ACURA MDX   3.7  (6 cyl)     Auto-S5   4WD
# 2           2008    ACURA RDX   2.3  (4 cyl)     Auto-S5   4WD
# 3           2008    ACURA RDX   2.3  (4 cyl)     Auto-S5   4WD
# 4           2008     ACURA RL   3.5  (6 cyl)     Auto-S5   4WD
# ...          ...          ...   ...      ...         ...   ...
# 3741        2018  VOLVO XC 90   2.0      4.0  SemiAuto-8   4WD
# 3742        2018  VOLVO XC 90   2.0      4.0  SemiAuto-8   4WD
# 3743        2018  VOLVO XC 90   2.0      4.0  SemiAuto-8   4WD
# 3744        2018  VOLVO XC 90   2.0      4.0  SemiAuto-8   4WD
# 3745        2018  VOLVO XC 90   2.0      4.0  SemiAuto-8   4WD
#
#                       fuel cert_region     veh_class air_pollution_score  \
# 0                 Gasoline          CA           SUV                   7
# ...

# %%
type(clean_df.greenhouse_gas_score[99])
# Out:
# str

# %%
clean_df.greenhouse_gas_score.value_counts()
# Out:
# 6      568
# 5      455
# 5      369
# 4      326
# 7      316
# 3      308
# 4      279
# 6      219
# 3      160
# 2      148
# 8      131
# 7      126
# 2       70
# 0       50
# 8       40
# 1       33
# 10      28
# 6/4     24
# 1       22
# 9       19
# 4/3     15
# 4/2     11
# 9       10
# 10       4
# 8/6      4
# 6/5      3
# 5/3      3
# 7/6      3
# 6/3      1
# 7/5      1
# Name: greenhouse_gas_score, dtype: int64

# %%
# extract all number values in the cylinder column
clean_df['cyl'] = clean_df['cyl'].astype('str').str.extractall('(\d+)').unstack().fillna('').sum(axis=1).astype(int)

# %%
v08 = clean_df.query('record_year == "2008"')
v18 = clean_df.query('record_year == "2018"')

# %%
v08.air_pollution_score = v08.air_pollution_score.astype('str').str.extractall('(^\d)').unstack().fillna('').sum(axis=1)
v18.air_pollution_score = v18.air_pollution_score.astype('float')

# %%
v08.air_pollution_score = v08.air_pollution_score.astype('str').str.extractall('(^\d)').unstack().fillna('').sum(axis=1)
v18.air_pollution_score = v18.air_pollution_score.astype('float')

# %%
v08.air_pollution_score = v08.air_pollution_score.astype('str').str.extractall('(^\d)').unstack().fillna('').sum(axis=1)
v18.air_pollution_score = v18.air_pollution_score.astype('float')

# %%
v08.air_pollution_score = v08.air_pollution_score.astype('str').str.extractall('(^\d)').unstack().fillna('').sum(axis=1)
v18.air_pollution_score = v18.air_pollution_score.astype('float')

# %%
v08.air_pollution_score = v08.air_pollution_score.astype('str').str.extractall('(^\d)').unstack().fillna('').sum(axis=1)

v18.city_mpg = v18.city_mpg.astype('str').str.extractall('(^\d{2})').unstack().fillna('').sum(axis=1)
v08.city_mpg = v08.city_mpg.astype('str').str.extractall('(^\d{2})').unstack().fillna('').sum(axis=1)
v08.hwy_mpg = v08.hwy_mpg.astype('str').str.extractall('(^\d{2})').unstack().fillna('').sum(axis=1)
v08.cmb_mpg = v08.cmb_mpg.astype('str').str.extractall('(^\d{2})').unstack().fillna('').sum(axis=1)


v18.city_mpg = v18.city_mpg.astype('str').str.extractall('(^\d{2})').unstack().fillna('').sum(axis=1)
v18.hwy_mpg = v18.hwy_mpg.astype('str').str.extractall('(^\d{2})').unstack().fillna('').sum(axis=1)
v18.cmb_mpg = v18.cmb_mpg.astype('str').str.extractall('(^\d{2})').unstack().fillna('').sum(axis=1)

# %%
clean_df.air_pollution_score.dtypes
# Out:
# dtype('float64')

# %%
v18
# Out:
#      record_year        model displ  cyl       trans drive  \
# 2142        2018    ACURA RDX   3.5  600  SemiAuto-6   2WD
# 2143        2018    ACURA RDX   3.5  600  SemiAuto-6   2WD
# 2144        2018    ACURA RDX   3.5  600  SemiAuto-6   4WD
# 2145        2018    ACURA RDX   3.5  600  SemiAuto-6   4WD
# 2146        2018    ACURA TLX   2.4  400       AMS-8   2WD
# ...          ...          ...   ...  ...         ...   ...
# 3741        2018  VOLVO XC 90   2.0  400  SemiAuto-8   4WD
# 3742        2018  VOLVO XC 90   2.0  400  SemiAuto-8   4WD
# 3743        2018  VOLVO XC 90   2.0  400  SemiAuto-8   4WD
# 3744        2018  VOLVO XC 90   2.0  400  SemiAuto-8   4WD
# 3745        2018  VOLVO XC 90   2.0  400  SemiAuto-8   4WD
#
#                       fuel cert_region     veh_class  air_pollution_score  \
# 2142              Gasoline          FA     small SUV                  3.0
# 2143              Gasoline          CA     small SUV                  3.0
# ...

# %%
v08
# Out:
#      record_year        model displ  cyl    trans drive      fuel cert_region  \
# 0           2008    ACURA MDX   3.7   60  Auto-S5   4WD  Gasoline          CA
# 1           2008    ACURA MDX   3.7   60  Auto-S5   4WD  Gasoline          FA
# 2           2008    ACURA RDX   2.3   40  Auto-S5   4WD  Gasoline          CA
# 3           2008    ACURA RDX   2.3   40  Auto-S5   4WD  Gasoline          FA
# 4           2008     ACURA RL   3.5   60  Auto-S5   4WD  Gasoline          CA
# ...          ...          ...   ...  ...      ...   ...       ...         ...
# 2137        2008  VOLVO XC 90   3.2   60  Auto-S6   4WD  Gasoline          CA
# 2138        2008  VOLVO XC 90   4.4   80  Auto-S6   4WD  Gasoline          CA
# 2139        2008  VOLVO XC 90   3.2   60  Auto-S6   2WD  Gasoline          FA
# 2140        2008  VOLVO XC 90   3.2   60  Auto-S6   4WD  Gasoline          FA
# 2141        2008  VOLVO XC 90   4.4   80  Auto-S6   4WD  Gasoline          FA
#
# ...

# %%
v08.greenhouse_gas_score = v08.greenhouse_gas_score.astype('str').str.extractall('(^\d)').unstack().fillna('').sum(axis=1).astype('int')

# %%
v08
# Out:
#      record_year        model displ  cyl    trans drive      fuel cert_region  \
# 0           2008    ACURA MDX   3.7   60  Auto-S5   4WD  Gasoline          CA
# 1           2008    ACURA MDX   3.7   60  Auto-S5   4WD  Gasoline          FA
# 2           2008    ACURA RDX   2.3   40  Auto-S5   4WD  Gasoline          CA
# 3           2008    ACURA RDX   2.3   40  Auto-S5   4WD  Gasoline          FA
# 4           2008     ACURA RL   3.5   60  Auto-S5   4WD  Gasoline          CA
# ...          ...          ...   ...  ...      ...   ...       ...         ...
# 2137        2008  VOLVO XC 90   3.2   60  Auto-S6   4WD  Gasoline          CA
# 2138        2008  VOLVO XC 90   4.4   80  Auto-S6   4WD  Gasoline          CA
# 2139        2008  VOLVO XC 90   3.2   60  Auto-S6   2WD  Gasoline          FA
# 2140        2008  VOLVO XC 90   3.2   60  Auto-S6   4WD  Gasoline          FA
# 2141        2008  VOLVO XC 90   4.4   80  Auto-S6   4WD  Gasoline          FA
#
# ...

# %%
clean_df = pd.concat([v08, v18])
