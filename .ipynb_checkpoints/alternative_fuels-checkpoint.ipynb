# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from fractions import Fraction

import plotly.express as px

pd.set_option('display.max_columns', None)
pd.options.mode.chained_assignment = None

# %matplotlib inline

# %%
#this is a custom function to open each dataset
def open_fuel_year(fuel_year):
    
    df = pd.read_csv('./clean_'+str(fuel_year)+'.csv', low_memory=False)
    
    return df

# %%
clean_df = pd.DataFrame()

years = [2008,2018]

#join the datasets
for fuel_year in years:
    clean_df = pd.concat([clean_df, open_fuel_year(fuel_year)])
    
    print(len(clean_df))
clean_df.reset_index(drop=True, inplace=True)
# Out:
# 2207
# 3890

# %%
clean_df
# Out:
#       Unnamed: 0  record_year        model  displ  cyl       trans drive  \
# 0              0         2008    ACURA MDX    3.7    6     Auto-S5   4WD
# 1              1         2008    ACURA MDX    3.7    6     Auto-S5   4WD
# 2              2         2008    ACURA RDX    2.3    4     Auto-S5   4WD
# 3              3         2008    ACURA RDX    2.3    4     Auto-S5   4WD
# 4              4         2008     ACURA RL    3.5    6     Auto-S5   4WD
# ...          ...          ...          ...    ...  ...         ...   ...
# 3885        1678         2018    VOLVO S90    2.0   40  SemiAuto-8   4WD
# 3886        1679         2018  VOLVO XC 60    2.0   40  SemiAuto-8   4WD
# 3887        1680         2018  VOLVO XC 60    2.0   40  SemiAuto-8   4WD
# 3888        1681         2018  VOLVO XC 90    2.0   40  SemiAuto-8   4WD
# 3889        1682         2018  VOLVO XC 90    2.0   40  SemiAuto-8   4WD
#
#              fuel cert_region     veh_class  air_pollution_score  city_mpg  \
# 0        Gasoline          CA           SUV                  7.0      15.0
# 1        Gasoline          FA           SUV                  6.0      15.0
# 2        Gasoline          CA           SUV                  7.0      17.0
# 3        Gasoline          FA           SUV                  6.0      17.0
# 4        Gasoline          CA   midsize car                  7.0      16.0
# ...           ...         ...           ...                  ...       ...
# 3885  Electricity          FA   midsize car                  7.0      70.0
# 3886  Electricity          CA     small SUV                  7.0      60.0
# 3887  Electricity          FA     small SUV                  7.0      60.0
# 3888  Electricity          CA  standard SUV                  7.0      63.0
# 3889  Electricity          FA  standard SUV                  7.0      63.0
#
#       hwy_mpg  cmb_mpg  greenhouse_gas_score smartway
# 0        20.0     17.0                     4       no
# 1        20.0     17.0                     4       no
# 2        22.0     19.0                     5       no
# 3        22.0     19.0                     5       no
# 4        24.0     19.0                     5       no
# ...       ...      ...                   ...      ...
# 3885     72.0     71.0                    10    Elite
# 3886     58.0     59.0                    10    Elite
# 3887     58.0     59.0                    10    Elite
# 3888     61.0     62.0                    10    Elite
# 3889     61.0     62.0                    10    Elite
#
# [3890 rows x 16 columns]

# %%
clean_df.drop(columns='Unnamed: 0', inplace=True)

# %%
clean_df
# Out:
#       record_year        model  displ  cyl       trans drive         fuel  \
# 0            2008    ACURA MDX    3.7    6     Auto-S5   4WD     Gasoline
# 1            2008    ACURA MDX    3.7    6     Auto-S5   4WD     Gasoline
# 2            2008    ACURA RDX    2.3    4     Auto-S5   4WD     Gasoline
# 3            2008    ACURA RDX    2.3    4     Auto-S5   4WD     Gasoline
# 4            2008     ACURA RL    3.5    6     Auto-S5   4WD     Gasoline
# ...           ...          ...    ...  ...         ...   ...          ...
# 3885         2018    VOLVO S90    2.0   40  SemiAuto-8   4WD  Electricity
# 3886         2018  VOLVO XC 60    2.0   40  SemiAuto-8   4WD  Electricity
# 3887         2018  VOLVO XC 60    2.0   40  SemiAuto-8   4WD  Electricity
# 3888         2018  VOLVO XC 90    2.0   40  SemiAuto-8   4WD  Electricity
# 3889         2018  VOLVO XC 90    2.0   40  SemiAuto-8   4WD  Electricity
#
#      cert_region     veh_class  air_pollution_score  city_mpg  hwy_mpg  \
# 0             CA           SUV                  7.0      15.0     20.0
# 1             FA           SUV                  6.0      15.0     20.0
# 2             CA           SUV                  7.0      17.0     22.0
# 3             FA           SUV                  6.0      17.0     22.0
# 4             CA   midsize car                  7.0      16.0     24.0
# ...          ...           ...                  ...       ...      ...
# 3885          FA   midsize car                  7.0      70.0     72.0
# 3886          CA     small SUV                  7.0      60.0     58.0
# 3887          FA     small SUV                  7.0      60.0     58.0
# 3888          CA  standard SUV                  7.0      63.0     61.0
# 3889          FA  standard SUV                  7.0      63.0     61.0
#
#       cmb_mpg  greenhouse_gas_score smartway
# 0        17.0                     4       no
# 1        17.0                     4       no
# 2        19.0                     5       no
# 3        19.0                     5       no
# 4        19.0                     5       no
# ...       ...                   ...      ...
# 3885     71.0                    10    Elite
# 3886     59.0                    10    Elite
# 3887     59.0                    10    Elite
# 3888     62.0                    10    Elite
# 3889     62.0                    10    Elite
#
# [3890 rows x 15 columns]

# %%
#clean_df.smartway.astype('str').lower()

# %%
v08 = clean_df.query('record_year == 2008')
v18 = clean_df.query('record_year == 2018')

# %% [markdown]
# ### Q1: Are more unique models using alternative sources of fuel? By how much?

# %%
v08.fuel.value_counts()
# Out:
# Gasoline    2067
# ethanol       66
# gas           65
# diesel         7
# CNG            2
# Name: fuel, dtype: int64

# %%
v18.fuel.value_counts()
# Out:
# Gasoline       1511
# Ethanol          55
# Gas              55
# Diesel           38
# Electricity      24
# Name: fuel, dtype: int64

# %%
# how many unique models used alternative sources of fuel in 2008
alt_08 = v08.query('fuel in ["CNG", "ethanol"]').model.nunique()
alt_08
# Out:
# 33

# %%
# how many unique models used alternative sources of fuel in 2018
alt_18 = v18.query('fuel in ["Electricity", "Gas"]').model.nunique()
alt_18
# Out:
# 28

# %%
plt.bar(["2008", "2018"], [alt_08, alt_18])
plt.title("Number of Unique Models Using Alternative Fuels")
plt.xlabel("Year")
plt.ylabel("Number of Unique Models");

# %%
# total unique models each year
total_08 = v08.model.nunique()
total_18 = v18.model.nunique()
total_08, total_18
# Out:
# (411, 366)

# %%
prop_08 = alt_08/total_08
prop_18 = alt_18/total_18
prop_08, prop_18
# Out:
# (0.08029197080291971, 0.07650273224043716)

# %%
plt.bar(["2008", "2018"], [prop_08, prop_18])
plt.title("Proportion of Unique Models Using Alternative Fuels")
plt.xlabel("Year")
plt.ylabel("Proportion of Unique Models");

# %% [markdown]
# ### Q2: How much have vehicle classes improved in fuel economy?

# %%
veh_08 = v08.groupby('veh_class').cmb_mpg.mean()
veh_08
# Out:
# veh_class
# SUV              17.920807
# large car        18.323308
# midsize car      21.395604
# minivan          18.666667
# pickup           16.060837
# small car        21.054896
# station wagon    22.349593
# van              14.206897
# Name: cmb_mpg, dtype: float64

# %%
veh_18 = v18.groupby('veh_class').cmb_mpg.mean()
veh_18
# Out:
# veh_class
# large car          23.372881
# midsize car        27.849462
# minivan            20.800000
# pickup             18.589744
# small SUV          23.986364
# small car          25.388889
# special purpose    18.666667
# standard SUV       18.197674
# station wagon      27.434783
# Name: cmb_mpg, dtype: float64

# %%
# how much they've increased by for each vehicle class
inc = veh_18 - veh_08
inc
# Out:
# veh_class
# SUV                     NaN
# large car          5.049573
# midsize car        6.453858
# minivan            2.133333
# pickup             2.528907
# small SUV               NaN
# small car          4.333993
# special purpose         NaN
# standard SUV            NaN
# station wagon      5.085189
# van                     NaN
# Name: cmb_mpg, dtype: float64

# %%
# only plot the classes that exist in both years
inc.dropna(inplace=True)
plt.subplots(figsize=(8, 5))
plt.bar(inc.index, inc)
plt.title('Improvements in Fuel Economy from 2008 to 2018 by Vehicle Class')
plt.xlabel('Vehicle Class')
plt.ylabel('Increase in Average Combined MPG');

# %% [markdown]
# ### Q3: What are the characteristics of SmartWay vehicles? Have they changed over time?

# %% [markdown]
# We can analyze this by filtering each dataframe by SmartWay classification and exploring these datasets.

# %%
# smartway labels for 2008
v08.smartway.unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
v18.smartway.unique()
# Out:
# array(['No', 'Yes', 'Elite'], dtype=object)

# %%
# get all smartway vehicles in 2008
smart_08 = v08.query('smartway == "yes"')

# %%
# get all smartway vehicles in 2018
smart_18 = v18.query('smartway in ["Yes", "Elite"]')

# %%
smart_18
# Out:
#       record_year            model  displ  cyl       trans drive         fuel  \
# 2240         2018    AUDI A4 Ultra    2.0   40       AMS-7   2WD     Gasoline
# 2241         2018    AUDI A4 Ultra    2.0   40       AMS-7   2WD     Gasoline
# 2450         2018     BUICK Encore    1.4   40  SemiAuto-6   2WD     Gasoline
# 2451         2018     BUICK Encore    1.4   40  SemiAuto-6   2WD     Gasoline
# 2546         2018  CHEVROLET Cruze    1.4   40       Man-6   2WD     Gasoline
# ...           ...              ...    ...  ...         ...   ...          ...
# 3885         2018        VOLVO S90    2.0   40  SemiAuto-8   4WD  Electricity
# 3886         2018      VOLVO XC 60    2.0   40  SemiAuto-8   4WD  Electricity
# 3887         2018      VOLVO XC 60    2.0   40  SemiAuto-8   4WD  Electricity
# 3888         2018      VOLVO XC 90    2.0   40  SemiAuto-8   4WD  Electricity
# 3889         2018      VOLVO XC 90    2.0   40  SemiAuto-8   4WD  Electricity
#
#      cert_region     veh_class  air_pollution_score  city_mpg  hwy_mpg  \
# 2240          CA     small car                  3.0      27.0     37.0
# 2241          FA     small car                  3.0      27.0     37.0
# 2450          CA     small SUV                  3.0      27.0     33.0
# 2451          FA     small SUV                  3.0      27.0     33.0
# 2546          CA     small car                  6.0      27.0     40.0
# ...          ...           ...                  ...       ...      ...
# 3885          FA   midsize car                  7.0      70.0     72.0
# 3886          CA     small SUV                  7.0      60.0     58.0
# 3887          FA     small SUV                  7.0      60.0     58.0
# 3888          CA  standard SUV                  7.0      63.0     61.0
# 3889          FA  standard SUV                  7.0      63.0     61.0
#
#       cmb_mpg  greenhouse_gas_score smartway
# 2240     31.0                     7      Yes
# 2241     31.0                     7      Yes
# 2450     30.0                     7      Yes
# 2451     30.0                     7      Yes
# 2546     32.0                     7      Yes
# ...       ...                   ...      ...
# 3885     71.0                    10    Elite
# 3886     59.0                    10    Elite
# 3887     59.0                    10    Elite
# 3888     62.0                    10    Elite
# 3889     62.0                    10    Elite
#
# [216 rows x 15 columns]

# %%
# explore smartway vehicles in 2008
smart_08.describe()
# Out:
#        record_year       displ         cyl  air_pollution_score   city_mpg  \
# count        625.0  625.000000  625.000000            625.00000  625.00000
# mean        2008.0    2.492320    4.664000              6.99680   21.45760
# std            0.0    0.584993    0.934935              1.14459    3.49751
# min         2008.0    1.300000    4.000000              6.00000   17.00000
# 25%         2008.0    2.000000    4.000000              6.00000   20.00000
# 50%         2008.0    2.400000    4.000000              7.00000   21.00000
# 75%         2008.0    2.700000    6.000000              7.00000   23.00000
# max         2008.0    5.000000    8.000000              9.50000   48.00000
#
#           hwy_mpg     cmb_mpg  greenhouse_gas_score
# count  625.000000  625.000000            625.000000
# mean    28.880000   24.201600              7.027200
# std      3.091552    3.086519              0.803176
# min     22.000000   20.000000              6.000000
# 25%     27.000000   22.000000              6.000000
# 50%     29.000000   24.000000              7.000000
# 75%     31.000000   25.000000              7.000000
# max     45.000000   46.000000             10.000000

# %%
# explore smartway vehicles in 2008
smart_18.describe()
# Out:
#        record_year       displ         cyl  air_pollution_score    city_mpg  \
# count        216.0  216.000000  216.000000           216.000000  216.000000
# mean        2018.0    1.787963   39.351852             5.194444   34.907407
# std            0.0    0.407081    4.153597             1.780819   16.393724
# min         2018.0    1.200000   30.000000             3.000000   25.000000
# 25%         2018.0    1.500000   40.000000             3.000000   28.000000
# 50%         2018.0    1.700000   40.000000             5.500000   28.500000
# 75%         2018.0    2.000000   40.000000             7.000000   31.250000
# max         2018.0    3.500000   60.000000             7.000000  113.000000
#
#           hwy_mpg     cmb_mpg  greenhouse_gas_score
# count  216.000000  216.000000            216.000000
# mean    41.472222   37.361111              7.925926
# std     13.064746   14.813858              1.194590
# min     27.000000   26.000000              7.000000
# 25%     36.000000   31.000000              7.000000
# 50%     37.000000   32.000000              7.000000
# 75%     40.250000   35.000000              9.000000
# max     99.000000  106.000000             10.000000

# %% [markdown]
# ### Q4: What features are associated with better fuel economy?

# %% [markdown]
# You can explore trends between cmb_mpg and the other features in this dataset, or filter this dataset like in the previous question and explore the properties of that dataset. For example, you can select all vehicles that have the top 50% fuel economy ratings like this.

# %%
top_08 = v08.query('cmb_mpg > cmb_mpg.mean()')
top_08.describe()
# Out:
#        record_year        displ          cyl  air_pollution_score  \
# count       1048.0  1048.000000  1048.000000          1048.000000
# mean        2008.0     2.663931     4.887405             6.557252
# std            0.0     0.674432     1.034604             1.102253
# min         2008.0     1.300000     4.000000             1.000000
# 25%         2008.0     2.300000     4.000000             6.000000
# 50%         2008.0     2.500000     4.000000             6.000000
# 75%         2008.0     3.000000     6.000000             7.000000
# max         2008.0     6.000000     8.000000             9.500000
#
#           city_mpg      hwy_mpg      cmb_mpg  greenhouse_gas_score
# count  1048.000000  1048.000000  1048.000000           1048.000000
# mean     20.249046    27.547710    22.921756              6.615458
# std       3.172229     3.069027     2.919418              0.810644
# min      17.000000    20.000000    20.000000              4.000000
# 25%      18.000000    25.000000    21.000000              6.000000
# 50%      20.000000    27.000000    22.000000              6.000000
# 75%      21.000000    29.000000    24.000000              7.000000
# max      48.000000    45.000000    46.000000             10.000000

# %%
top_18 = v18.query('cmb_mpg > cmb_mpg.mean()')
top_18.describe()
# Out:
#        record_year       displ         cyl  air_pollution_score    city_mpg  \
# count        765.0  765.000000  765.000000           765.000000  765.000000
# mean        2018.0    2.060131   41.647059             4.683660   26.592157
# std            0.0    0.483597    6.722307             1.864327   10.437721
# min         2018.0    1.200000   30.000000             1.000000   20.000000
# 25%         2018.0    1.800000   40.000000             3.000000   22.000000
# 50%         2018.0    2.000000   40.000000             5.000000   24.000000
# 75%         2018.0    2.000000   40.000000             7.000000   27.000000
# max         2018.0    3.600000   60.000000             7.000000  113.000000
#
#           hwy_mpg     cmb_mpg  greenhouse_gas_score
# count  765.000000  765.000000            765.000000
# mean    34.384314   29.504575              6.141176
# std      8.663051    9.590519              1.384636
# min     27.000000   24.000000              4.000000
# 25%     30.000000   25.000000              5.000000
# 50%     32.000000   27.000000              6.000000
# 75%     36.000000   30.000000              7.000000
# max     99.000000  106.000000             10.000000

# %% [markdown]
# ### Q5: For all the models produced in 2008 that are still in production in 2018, how much has the mpg improved and which vehicle has improved the most?
#
# Take a list of all models being produeced in 2008 and filter it into a list. Compare the list to vehicles being produced in 2018

# %%
unique08 = v08.model.unique()

# %%
unique18 = v18.model.unique()

# %%
unique08 = list(unique08)

# %%
same_both = v18.query('model in @unique08')

# %%
same_both = pd.merge(v08, v18, on=['model', 'trans'])

# %%
same_both
# Out:
#     record_year_x                 model  displ_x  cyl_x   trans drive_x  \
# 0            2008               AUDI A4      3.1      6   Man-6     4WD
# 1            2008               AUDI A4      3.1      6   Man-6     4WD
# 2            2008               AUDI A4      3.1      6   Man-6     4WD
# 3            2008               AUDI A4      3.1      6   Man-6     4WD
# 4            2008    BMW M6 Convertible      5.0     10   Man-6     2WD
# 5            2008    BMW M6 Convertible      5.0     10   Man-6     2WD
# 6            2008    BMW M6 Convertible      5.0     10   Man-6     2WD
# 7            2008    BMW M6 Convertible      5.0     10   Man-6     2WD
# 8            2008  MASERATI Granturismo      4.2      8  Auto-6     2WD
# 9            2008  MASERATI Granturismo      4.2      8  Auto-6     2WD
# 10           2008  MASERATI Granturismo      4.2      8  Auto-6     2WD
# 11           2008  MASERATI Granturismo      4.2      8  Auto-6     2WD
# 12           2008               MAZDA 3      2.3      4   Man-6     2WD
# 13           2008               MAZDA 3      2.3      4   Man-6     2WD
# 14           2008               MAZDA 3      2.3      4   Man-6     2WD
# 15           2008               MAZDA 3      2.3      4   Man-6     2WD
# 16           2008               MAZDA 3      2.3      4   Man-6     2WD
# 17           2008               MAZDA 3      2.3      4   Man-6     2WD
# 18           2008               MAZDA 3      2.3      4   Man-6     2WD
# 19           2008               MAZDA 3      2.3      4   Man-6     2WD
# 20           2008       PORSCHE Boxster      2.7      6   Man-6     2WD
# 21           2008       PORSCHE Boxster      2.7      6   Man-6     2WD
# 22           2008       PORSCHE Boxster      2.7      6   Man-6     2WD
# 23           2008       PORSCHE Boxster      2.7      6   Man-6     2WD
# 24           2008     PORSCHE Boxster S      3.4      6   Man-6     2WD
# 25           2008     PORSCHE Boxster S      3.4      6   Man-6     2WD
# 26           2008     PORSCHE Boxster S      3.4      6   Man-6     2WD
# 27           2008     PORSCHE Boxster S      3.4      6   Man-6     2WD
# 28           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 29           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 30           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 31           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 32           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 33           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 34           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 35           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 36           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 37           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 38           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 39           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 40           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 41           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 42           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 43           2008        SUBARU Impreza      2.5      4   Man-5     4WD
# 44           2008          TOYOTA Yaris      1.5      4   Man-5     2WD
# 45           2008          TOYOTA Yaris      1.5      4   Man-5     2WD
# 46           2008          TOYOTA Yaris      1.5      4   Man-5     2WD
# 47           2008          TOYOTA Yaris      1.5      4   Man-5     2WD
# 48           2008      VOLKSWAGEN Jetta      2.5      5   Man-5     2WD
# 49           2008      VOLKSWAGEN Jetta      2.5      5   Man-5     2WD
# 50           2008      VOLKSWAGEN Jetta      2.5      5   Man-5     2WD
# 51           2008      VOLKSWAGEN Jetta      2.5      5   Man-5     2WD
# 52           2008      VOLKSWAGEN Jetta      2.5      5   Man-5     2WD
# 53           2008      VOLKSWAGEN Jetta      2.5      5   Man-5     2WD
# 54           2008      VOLKSWAGEN Jetta      2.5      5   Man-5     2WD
# 55           2008      VOLKSWAGEN Jetta      2.5      5   Man-5     2WD
#
#       fuel_x cert_region_x  veh_class_x  air_pollution_score_x  city_mpg_x  \
# 0   Gasoline            FA    small car                    6.0        15.0
# 1   Gasoline            FA    small car                    6.0        15.0
# 2   Gasoline            CA    small car                    6.0        15.0
# 3   Gasoline            CA    small car                    6.0        15.0
# 4   Gasoline            FA    small car                    6.0        12.0
# 5   Gasoline            FA    small car                    6.0        12.0
# 6   Gasoline            CA    small car                    6.0        12.0
# 7   Gasoline            CA    small car                    6.0        12.0
# 8   Gasoline            FA    small car                    6.0        14.0
# 9   Gasoline            FA    small car                    6.0        14.0
# 10  Gasoline            CA    small car                    6.0        14.0
# 11  Gasoline            CA    small car                    6.0        14.0
# 12  Gasoline            CA  midsize car                    7.0        18.0
# 13  Gasoline            CA  midsize car                    7.0        18.0
# 14  Gasoline            CA  midsize car                    7.0        18.0
# 15  Gasoline            CA  midsize car                    7.0        18.0
# 16  Gasoline            FA  midsize car                    6.0        18.0
# 17  Gasoline            FA  midsize car                    6.0        18.0
# 18  Gasoline            FA  midsize car                    6.0        18.0
# 19  Gasoline            FA  midsize car                    6.0        18.0
# 20  Gasoline            CA    small car                    7.0        19.0
# 21  Gasoline            CA    small car                    7.0        19.0
# 22  Gasoline            FA    small car                    6.0        19.0
# 23  Gasoline            FA    small car                    6.0        19.0
# 24  Gasoline            CA    small car                    7.0        18.0
# 25  Gasoline            CA    small car                    7.0        18.0
# 26  Gasoline            FA    small car                    6.0        18.0
# 27  Gasoline            FA    small car                    6.0        18.0
# 28  Gasoline            FA    small car                    6.0        19.0
# 29  Gasoline            FA    small car                    6.0        19.0
# 30  Gasoline            FA    small car                    6.0        19.0
# 31  Gasoline            FA    small car                    6.0        19.0
# 32  Gasoline            FA    small car                    6.0        20.0
# 33  Gasoline            FA    small car                    6.0        20.0
# 34  Gasoline            FA    small car                    6.0        20.0
# 35  Gasoline            FA    small car                    6.0        20.0
# 36  Gasoline            CA    small car                    6.0        19.0
# 37  Gasoline            CA    small car                    6.0        19.0
# 38  Gasoline            CA    small car                    6.0        19.0
# 39  Gasoline            CA    small car                    6.0        19.0
# 40  Gasoline            CA    small car                    6.0        20.0
# 41  Gasoline            CA    small car                    6.0        20.0
# 42  Gasoline            CA    small car                    6.0        20.0
# 43  Gasoline            CA    small car                    6.0        20.0
# 44  Gasoline            CA    small car                    7.0        29.0
# 45  Gasoline            CA    small car                    7.0        29.0
# 46  Gasoline            FA    small car                    6.0        29.0
# 47  Gasoline            FA    small car                    6.0        29.0
# 48  Gasoline            CA    small car                    9.5        21.0
# 49  Gasoline            CA    small car                    9.5        21.0
# 50  Gasoline            FA    small car                    9.0        21.0
# 51  Gasoline            FA    small car                    9.0        21.0
# 52  Gasoline            CA    small car                    7.0        21.0
# 53  Gasoline            CA    small car                    7.0        21.0
# 54  Gasoline            FA    small car                    6.0        21.0
# 55  Gasoline            FA    small car                    6.0        21.0
#
#     hwy_mpg_x  cmb_mpg_x  greenhouse_gas_score_x smartway_x  record_year_y  \
# 0        25.0       19.0                       5         no           2018
# 1        25.0       19.0                       5         no           2018
# 2        25.0       19.0                       5         no           2018
# 3        25.0       19.0                       5         no           2018
# 4        18.0       14.0                       2         no           2018
# 5        18.0       14.0                       2         no           2018
# 6        18.0       14.0                       2         no           2018
# 7        18.0       14.0                       2         no           2018
# 8        21.0       17.0                       4         no           2018
# 9        21.0       17.0                       4         no           2018
# 10       21.0       17.0                       4         no           2018
# 11       21.0       17.0                       4         no           2018
# 12       26.0       20.0                       6        yes           2018
# 13       26.0       20.0                       6        yes           2018
# 14       26.0       20.0                       6        yes           2018
# 15       26.0       20.0                       6        yes           2018
# 16       26.0       20.0                       6         no           2018
# 17       26.0       20.0                       6         no           2018
# 18       26.0       20.0                       6         no           2018
# 19       26.0       20.0                       6         no           2018
# 20       28.0       22.0                       6        yes           2018
# 21       28.0       22.0                       6        yes           2018
# 22       28.0       22.0                       6         no           2018
# 23       28.0       22.0                       6         no           2018
# 24       26.0       21.0                       6        yes           2018
# 25       26.0       21.0                       6        yes           2018
# 26       26.0       21.0                       6         no           2018
# 27       26.0       21.0                       6         no           2018
# 28       25.0       21.0                       6         no           2018
# 29       25.0       21.0                       6         no           2018
# 30       25.0       21.0                       6         no           2018
# 31       25.0       21.0                       6         no           2018
# 32       27.0       22.0                       6         no           2018
# 33       27.0       22.0                       6         no           2018
# 34       27.0       22.0                       6         no           2018
# 35       27.0       22.0                       6         no           2018
# 36       25.0       21.0                       6         no           2018
# 37       25.0       21.0                       6         no           2018
# 38       25.0       21.0                       6         no           2018
# 39       25.0       21.0                       6         no           2018
# 40       27.0       22.0                       6         no           2018
# 41       27.0       22.0                       6         no           2018
# 42       27.0       22.0                       6         no           2018
# 43       27.0       22.0                       6         no           2018
# 44       36.0       32.0                       9        yes           2018
# 45       36.0       32.0                       9        yes           2018
# 46       36.0       32.0                       9        yes           2018
# 47       36.0       32.0                       9        yes           2018
# 48       29.0       24.0                       7        yes           2018
# 49       29.0       24.0                       7        yes           2018
# 50       29.0       24.0                       7        yes           2018
# 51       29.0       24.0                       7        yes           2018
# 52       29.0       24.0                       7        yes           2018
# 53       29.0       24.0                       7        yes           2018
# 54       29.0       24.0                       7        yes           2018
# 55       29.0       24.0                       7        yes           2018
#
#     displ_y  cyl_y drive_y    fuel_y cert_region_y    veh_class_y  \
# 0       2.0     40     4WD  Gasoline            CA      small car
# 1       2.0     40     4WD  Gasoline            FA      small car
# 2       2.0     40     4WD  Gasoline            CA      small car
# 3       2.0     40     4WD  Gasoline            FA      small car
# 4       4.4     80     2WD  Gasoline            CA      small car
# 5       4.4     80     2WD  Gasoline            FA      small car
# 6       4.4     80     2WD  Gasoline            CA      small car
# 7       4.4     80     2WD  Gasoline            FA      small car
# 8       4.7     80     2WD  Gasoline            CA      small car
# 9       4.7     80     2WD  Gasoline            FA      small car
# 10      4.7     80     2WD  Gasoline            CA      small car
# 11      4.7     80     2WD  Gasoline            FA      small car
# 12      2.0     40     2WD  Gasoline            CA    midsize car
# 13      2.0     40     2WD  Gasoline            CA      small car
# 14      2.0     40     2WD  Gasoline            FA    midsize car
# 15      2.0     40     2WD  Gasoline            FA      small car
# 16      2.0     40     2WD  Gasoline            CA    midsize car
# 17      2.0     40     2WD  Gasoline            CA      small car
# 18      2.0     40     2WD  Gasoline            FA    midsize car
# 19      2.0     40     2WD  Gasoline            FA      small car
# 20      2.0     40     2WD  Gasoline            CA      small car
# 21      2.0     40     2WD  Gasoline            FA      small car
# 22      2.0     40     2WD  Gasoline            CA      small car
# 23      2.0     40     2WD  Gasoline            FA      small car
# 24      2.5     40     2WD  Gasoline            CA      small car
# 25      2.5     40     2WD  Gasoline            FA      small car
# 26      2.5     40     2WD  Gasoline            CA      small car
# 27      2.5     40     2WD  Gasoline            FA      small car
# 28      2.0     40     4WD  Gasoline            CA    midsize car
# 29      2.0     40     4WD  Gasoline            CA  station wagon
# 30      2.0     40     4WD  Gasoline            FA    midsize car
# 31      2.0     40     4WD  Gasoline            FA  station wagon
# 32      2.0     40     4WD  Gasoline            CA    midsize car
# 33      2.0     40     4WD  Gasoline            CA  station wagon
# 34      2.0     40     4WD  Gasoline            FA    midsize car
# 35      2.0     40     4WD  Gasoline            FA  station wagon
# 36      2.0     40     4WD  Gasoline            CA    midsize car
# 37      2.0     40     4WD  Gasoline            CA  station wagon
# 38      2.0     40     4WD  Gasoline            FA    midsize car
# 39      2.0     40     4WD  Gasoline            FA  station wagon
# 40      2.0     40     4WD  Gasoline            CA    midsize car
# 41      2.0     40     4WD  Gasoline            CA  station wagon
# 42      2.0     40     4WD  Gasoline            FA    midsize car
# 43      2.0     40     4WD  Gasoline            FA  station wagon
# 44      1.5     40     2WD  Gasoline            FA      small car
# 45      1.5     40     2WD  Gasoline            CA      small car
# 46      1.5     40     2WD  Gasoline            FA      small car
# 47      1.5     40     2WD  Gasoline            CA      small car
# 48      1.4     40     2WD  Gasoline            FA      small car
# 49      1.4     40     2WD  Gasoline            CA      small car
# 50      1.4     40     2WD  Gasoline            FA      small car
# 51      1.4     40     2WD  Gasoline            CA      small car
# 52      1.4     40     2WD  Gasoline            FA      small car
# 53      1.4     40     2WD  Gasoline            CA      small car
# 54      1.4     40     2WD  Gasoline            FA      small car
# 55      1.4     40     2WD  Gasoline            CA      small car
#
#     air_pollution_score_y  city_mpg_y  hwy_mpg_y  cmb_mpg_y  \
# 0                     3.0        24.0       33.0       27.0
# 1                     3.0        24.0       33.0       27.0
# 2                     3.0        24.0       33.0       27.0
# 3                     3.0        24.0       33.0       27.0
# 4                     1.0        15.0       22.0       17.0
# 5                     1.0        15.0       22.0       17.0
# 6                     1.0        15.0       22.0       17.0
# 7                     1.0        15.0       22.0       17.0
# 8                     1.0        13.0       21.0       16.0
# 9                     1.0        13.0       21.0       16.0
# 10                    1.0        13.0       21.0       16.0
# 11                    1.0        13.0       21.0       16.0
# 12                    7.0        27.0       37.0       31.0
# 13                    7.0        28.0       38.0       31.0
# 14                    7.0        27.0       37.0       31.0
# 15                    7.0        28.0       38.0       31.0
# 16                    7.0        27.0       37.0       31.0
# 17                    7.0        28.0       38.0       31.0
# 18                    7.0        27.0       37.0       31.0
# 19                    7.0        28.0       38.0       31.0
# 20                    3.0        21.0       28.0       24.0
# 21                    3.0        21.0       28.0       24.0
# 22                    3.0        21.0       28.0       24.0
# 23                    3.0        21.0       28.0       24.0
# 24                    3.0        20.0       26.0       22.0
# 25                    3.0        20.0       26.0       22.0
# 26                    3.0        20.0       26.0       22.0
# 27                    3.0        20.0       26.0       22.0
# 28                    7.0        24.0       32.0       27.0
# 29                    7.0        24.0       31.0       26.0
# 30                    6.0        24.0       32.0       27.0
# 31                    6.0        24.0       31.0       26.0
# 32                    7.0        24.0       32.0       27.0
# 33                    7.0        24.0       31.0       26.0
# 34                    6.0        24.0       32.0       27.0
# 35                    6.0        24.0       31.0       26.0
# 36                    7.0        24.0       32.0       27.0
# 37                    7.0        24.0       31.0       26.0
# 38                    6.0        24.0       32.0       27.0
# 39                    6.0        24.0       31.0       26.0
# 40                    7.0        24.0       32.0       27.0
# 41                    7.0        24.0       31.0       26.0
# 42                    6.0        24.0       32.0       27.0
# 43                    6.0        24.0       31.0       26.0
# 44                    3.0        30.0       36.0       33.0
# 45                    3.0        30.0       36.0       33.0
# 46                    3.0        30.0       36.0       33.0
# 47                    3.0        30.0       36.0       33.0
# 48                    3.0        28.0       40.0       33.0
# 49                    3.0        28.0       40.0       33.0
# 50                    3.0        28.0       40.0       33.0
# 51                    3.0        28.0       40.0       33.0
# 52                    3.0        28.0       40.0       33.0
# 53                    3.0        28.0       40.0       33.0
# 54                    3.0        28.0       40.0       33.0
# 55                    3.0        28.0       40.0       33.0
#
#     greenhouse_gas_score_y smartway_y
# 0                        6         No
# 1                        6         No
# 2                        6         No
# 3                        6         No
# 4                        3         No
# 5                        3         No
# 6                        3         No
# 7                        3         No
# 8                        2         No
# 9                        2         No
# 10                       2         No
# 11                       2         No
# 12                       7        Yes
# 13                       7        Yes
# 14                       7        Yes
# 15                       7        Yes
# 16                       7        Yes
# 17                       7        Yes
# 18                       7        Yes
# 19                       7        Yes
# 20                       5         No
# 21                       5         No
# 22                       5         No
# 23                       5         No
# 24                       4         No
# 25                       4         No
# 26                       4         No
# 27                       4         No
# 28                       6         No
# 29                       5         No
# 30                       6         No
# 31                       5         No
# 32                       6         No
# 33                       5         No
# 34                       6         No
# 35                       5         No
# 36                       6         No
# 37                       5         No
# 38                       6         No
# 39                       5         No
# 40                       6         No
# 41                       5         No
# 42                       6         No
# 43                       5         No
# 44                       8        Yes
# 45                       8        Yes
# 46                       8        Yes
# 47                       8        Yes
# 48                       8        Yes
# 49                       8        Yes
# 50                       8        Yes
# 51                       8        Yes
# 52                       8        Yes
# 53                       8        Yes
# 54                       8        Yes
# 55                       8        Yes

# %%
same_both.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 412 entries, 0 to 411
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   record_year_x           412 non-null    int64
#  1   model                   412 non-null    object
#  2   displ_x                 412 non-null    float64
#  3   cyl_x                   412 non-null    int64
#  4   trans_x                 412 non-null    object
#  5   drive_x                 412 non-null    object
#  6   fuel_x                  412 non-null    object
#  7   cert_region_x           412 non-null    object
#  8   veh_class_x             412 non-null    object
#  9   air_pollution_score_x   412 non-null    float64
#  10  city_mpg_x              412 non-null    float64
#  11  hwy_mpg_x               412 non-null    float64
#  12  cmb_mpg                 412 non-null    float64
#  13  greenhouse_gas_score_x  412 non-null    int64
#  14  smartway_x              412 non-null    object
#  15  record_year_y           412 non-null    int64
#  16  displ_y                 412 non-null    float64
#  17  cyl_y                   412 non-null    int64
#  18  trans_y                 412 non-null    object
#  19  drive_y                 412 non-null    object
#  20  fuel_y                  412 non-null    object
#  21  cert_region_y           412 non-null    object
#  22  veh_class_y             412 non-null    object
#  23  air_pollution_score_y   412 non-null    float64
#  24  city_mpg_y              412 non-null    float64
#  25  hwy_mpg_y               412 non-null    float64
#  26  greenhouse_gas_score_y  412 non-null    int64
#  27  smartway_y              412 non-null    object
# dtypes: float64(9), int64(6), object(13)
# memory usage: 93.3+ KB

# %%
same_both[['model', 'record_year_x', 'record_year_y', 'cmb_mpg', 'cmb_mpg_y']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [252], in <cell line: 1>()
# ----> 1 same_both[['model', 'record_year_x', 'record_year_y', 'cmb_mpg_x', 'cmb_mpg_y']]
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['cmb_mpg_x', 'cmb_mpg_y'] not in index"
